# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report,r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, ElasticNet
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
from catboost import CatBoostRegressor

# %%
train =pd.read_csv("D:/Machine Learning/Kaggle_COM_ML/ML_Assgn_3_Tabular_Playgrd/tabular-playground-series-mar-2022/train.csv",index_col=0)
train
# Out:
#                        time  x  y direction  congestion
# row_id
# 0       1991-04-01 00:00:00  0  0        EB          70
# 1       1991-04-01 00:00:00  0  0        NB          49
# 2       1991-04-01 00:00:00  0  0        SB          24
# 3       1991-04-01 00:00:00  0  1        EB          18
# 4       1991-04-01 00:00:00  0  1        NB          60
# ...                     ... .. ..       ...         ...
# 848830  1991-09-30 11:40:00  2  3        NB          54
# 848831  1991-09-30 11:40:00  2  3        NE          28
# 848832  1991-09-30 11:40:00  2  3        SB          68
# 848833  1991-09-30 11:40:00  2  3        SW          17
# 848834  1991-09-30 11:40:00  2  3        WB          24
#
# [848835 rows x 5 columns]

# %%
test =pd.read_csv("D:/Machine Learning/Kaggle_COM_ML/ML_Assgn_3_Tabular_Playgrd/tabular-playground-series-mar-2022/test.csv")
test
# Out:
#       row_id                 time  x  y direction
# 0     848835  1991-09-30 12:00:00  0  0        EB
# 1     848836  1991-09-30 12:00:00  0  0        NB
# 2     848837  1991-09-30 12:00:00  0  0        SB
# 3     848838  1991-09-30 12:00:00  0  1        EB
# 4     848839  1991-09-30 12:00:00  0  1        NB
# ...      ...                  ... .. ..       ...
# 2335  851170  1991-09-30 23:40:00  2  3        NB
# 2336  851171  1991-09-30 23:40:00  2  3        NE
# 2337  851172  1991-09-30 23:40:00  2  3        SB
# 2338  851173  1991-09-30 23:40:00  2  3        SW
# 2339  851174  1991-09-30 23:40:00  2  3        WB
#
# [2340 rows x 5 columns]

# %%
'''Linear Regression
ElasticNet Regression
XGBoost
CatBoost
LightGBM

Mention leaderboard scores for each of the five.

'''
# Out:
# 'Linear Regression\nElasticNet Regression\nXGBoost\nCatBoost\nLightGBM\n\nMention leaderboard scores for each of the five.\n\n'

# %%
le = LabelEncoder()

dir_en=pd.DataFrame(le.fit_transform(train['direction']))
X_train = train.drop(['time', 'congestion','direction'], axis=1)
X_train['direction']=dir_en

# y_train = np.log(train['congestion'])

# y_train=np.ceil(y_train)
y_train =(train['congestion'])
# count = 0
# for val in y_train:
#     if val == np.inf or val == -np.inf:
#         count += 1
#         print(val)
# count

# %%
d_en=pd.DataFrame(le.fit_transform(test['direction']))
X_test =  test.drop(['time','row_id','direction'], axis=1)
X_test['direction']=dir_en

print(X_train.columns)
print(X_test.columns)
# Out:
# Index(['x', 'y', 'direction'], dtype='object')
# Index(['x', 'y', 'direction'], dtype='object')

# %%
X_train
# Out:
#         x  y  direction
# row_id
# 0       0  0          0
# 1       0  0          1
# 2       0  0          4
# 3       0  1          0
# 4       0  1          1
# ...    .. ..        ...
# 848830  2  3          1
# 848831  2  3          2
# 848832  2  3          4
# 848833  2  3          6
# 848834  2  3          7
#
# [848835 rows x 3 columns]

# %%
X_test
# Out:
#       x  y  direction
# 0     0  0          0
# 1     0  0          1
# 2     0  0          4
# 3     0  1          0
# 4     0  1          1
# ...  .. ..        ...
# 2335  2  3          1
# 2336  2  3          2
# 2337  2  3          4
# 2338  2  3          6
# 2339  2  3          7
#
# [2340 rows x 3 columns]

# %%
#using Linear regression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# y_pred=np.log(y_pred)
# Out:
# array([49.77233399, 49.50110549, 48.68742001, ..., 46.59540975,
#        46.05295275, 45.78172426])

# %%
submit=pd.DataFrame({'row_id':test['row_id'],'congestion':y_pred})

# %%
submit.to_csv('linear_tabular_playground_without_time.csv',index=False)

# %%
#using elasticnet

# %%
el=ElasticNet(alpha=0.4, l1_ratio=0.2)

# %%
el.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 el.fit(X_train,y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:955, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#     953 if check_input:
#     954     X_copied = self.copy_X and self.fit_intercept
# --> 955     X, y = self._validate_data(
#     956         X,
#     957         y,
#     958         accept_sparse="csc",
#     959         order="F",
#     960         dtype=[np.float64, np.float32],
#     961         copy=X_copied,
#     962         multi_output=True,
#     963         y_numeric=True,
#     964     )
#     965     y = check_array(
#     966         y, order="F", copy=False, dtype=X.dtype.type, ensure_2d=False
#     967     )
#     969 n_samples, n_features = X.shape
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1279, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259     raise ValueError(
#    1260         f"{estimator_name} requires y to be passed, but the target y is None"
#    1261     )
#    1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    (...)
#    1276     input_name="X",
#    1277 )
# -> 1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1281 check_consistent_length(X, y)
#    1283 return X, y
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1289, in _check_y(y, multi_output, y_numeric, estimator)
#    1287 """Isolated part of check_X_y dedicated to y validation"""
#    1288 if multi_output:
# -> 1289     y = check_array(
#    1290         y,
#    1291         accept_sparse="csr",
#    1292         force_all_finite=True,
#    1293         ensure_2d=False,
#    1294         dtype=None,
#    1295         input_name="y",
#    1296         estimator=estimator,
#    1297     )
#    1298 else:
#    1299     estimator_name = _check_estimator_name(estimator)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input y contains infinity or a value too large for dtype('float64').

# %%
y_pred=lr.predict(X_test)
y_pred=np.log(y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 y_pred=lr.predict(X_test)
#       2 y_pred=np.log(y_pred)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py:270, in LinearModel._decision_function(self, X)
#     267 check_is_fitted(self)
#     269 X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 270 return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
submit=pd.DataFrame({'row_id':test['row_id'],'congestion':y_pred})

# %%
submit.to_csv('elastic_tabular_playground.csv',index=False)

# %%
#using lightGBM

# %%
lgb=LGBMRegressor()

# %%
lgb.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 217, in _count_physical_cores
#     raise ValueError(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 15
# [LightGBM] [Info] Number of data points in the train set: 848835, number of used features: 3
# [LightGBM] [Info] Start training from score 47.815305
# LGBMRegressor()

# %%
y_pred=lgb.predict(X_test)
# y_pred=np.exp(y_pred)

# %%
submit=pd.DataFrame({'row_id':test['row_id'],'congestion':y_pred})

# %%
submit.to_csv('LGB_Tabular_Playground_without_time.csv',index=False)

# %%
#using xgb

# %%
xgb = XGBRegressor(random_state=24)

# %%
xgb.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 xgb.fit(X_train,y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:1055, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1053 with config_context(verbosity=self.verbosity):
#    1054     evals_result: TrainingCallback.EvalsLog = {}
# -> 1055     train_dmatrix, evals = _wrap_evaluation_matrices(
#    1056         missing=self.missing,
#    1057         X=X,
#    1058         y=y,
#    1059         group=None,
#    1060         qid=None,
#    1061         sample_weight=sample_weight,
#    1062         base_margin=base_margin,
#    1063         feature_weights=feature_weights,
#    1064         eval_set=eval_set,
#    1065         sample_weight_eval_set=sample_weight_eval_set,
#    1066         base_margin_eval_set=base_margin_eval_set,
#    1067         eval_group=None,
#    1068         eval_qid=None,
#    1069         create_dmatrix=self._create_dmatrix,
#    1070         enable_categorical=self.enable_categorical,
#    1071         feature_types=self.feature_types,
#    1072     )
#    1073     params = self.get_xgb_params()
#    1075     if callable(self.objective):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:521, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     501 def _wrap_evaluation_matrices(
#     502     missing: float,
#     503     X: Any,
#    (...)
#     517     feature_types: Optional[FeatureTypes],
#     518 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     519     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     520     way."""
# --> 521     train_dmatrix = create_dmatrix(
#     522         data=X,
#     523         label=y,
#     524         group=group,
#     525         qid=qid,
#     526         weight=sample_weight,
#     527         base_margin=base_margin,
#     528         feature_weights=feature_weights,
#     529         missing=missing,
#     530         enable_categorical=enable_categorical,
#     531         feature_types=feature_types,
#     532         ref=None,
#     533     )
#     535     n_validation = 0 if eval_set is None else len(eval_set)
#     537     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\sklearn.py:958, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     956 if _can_use_qdm(self.tree_method) and self.booster != "gblinear":
#     957     try:
# --> 958         return QuantileDMatrix(
#     959             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#     960         )
#     961     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     962         pass
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:1529, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#    1509     if any(
#    1510         info is not None
#    1511         for info in (
#    (...)
#    1522         )
#    1523     ):
#    1524         raise ValueError(
#    1525             "If data iterator is used as input, data like label should be "
#    1526             "specified as batch argument."
#    1527         )
# -> 1529 self._init(
#    1530     data,
#    1531     ref=ref,
#    1532     label=label,
#    1533     weight=weight,
#    1534     base_margin=base_margin,
#    1535     group=group,
#    1536     qid=qid,
#    1537     label_lower_bound=label_lower_bound,
#    1538     label_upper_bound=label_upper_bound,
#    1539     feature_weights=feature_weights,
#    1540     feature_names=feature_names,
#    1541     feature_types=feature_types,
#    1542     enable_categorical=enable_categorical,
#    1543 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:1588, in QuantileDMatrix._init(self, data, ref, enable_categorical, **meta)
#    1576 config = make_jcargs(
#    1577     nthread=self.nthread, missing=self.missing, max_bin=self.max_bin
#    1578 )
#    1579 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1580     None,
#    1581     it.proxy.handle,
#    (...)
#    1586     ctypes.byref(handle),
#    1587 )
# -> 1588 it.reraise()
#    1589 # delay check_call to throw intermediate exception first
#    1590 _check_call(ret)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:576, in DataIter.reraise(self)
#     574 exc = self._exception
#     575 self._exception = None
# --> 576 raise exc
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:557, in DataIter._handle_exception(self, fn, dft_ret)
#     554     return dft_ret
#     556 try:
# --> 557     return fn()
#     558 except Exception as e:  # pylint: disable=broad-except
#     559     # Defer the exception in order to return 0 and stop the iteration.
#     560     # Exception inside a ctype callback function has no effect except
#     561     # for printing to stderr (doesn't stop the execution).
#     562     tb = sys.exc_info()[2]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:641, in DataIter._next_wrapper.<locals>.<lambda>()
#     638     self._data_ref = ref
#     640 # pylint: disable=not-callable
# --> 641 return self._handle_exception(lambda: self.next(input_data), 0)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\data.py:1280, in SingleBatchInternalIter.next(self, input_data)
#    1278     return 0
#    1279 self.it += 1
# -> 1280 input_data(**self.kwargs)
#    1281 return 1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:633, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     631 self._temporary_data = (new, cat_codes, feature_names, feature_types)
#     632 dispatch_proxy_set_data(self.proxy, new, cat_codes, self._allow_host)
# --> 633 self.proxy.set_info(
#     634     feature_names=feature_names,
#     635     feature_types=feature_types,
#     636     **kwargs,
#     637 )
#     638 self._data_ref = ref
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:932, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     929 from .data import dispatch_meta_backend
#     931 if label is not None:
# --> 932     self.set_label(label)
#     933 if weight is not None:
#     934     self.set_weight(weight)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:1070, in DMatrix.set_label(self, label)
#    1061 """Set label of dmatrix
#    1062
#    1063 Parameters
#    (...)
#    1066     The label information to be set into DMatrix
#    1067 """
#    1068 from .data import dispatch_meta_backend
# -> 1070 dispatch_meta_backend(self, label, "label", "float")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\data.py:1225, in dispatch_meta_backend(matrix, data, name, dtype)
#    1223     return
#    1224 if _is_pandas_series(data):
# -> 1225     _meta_from_pandas_series(data, name, dtype, handle)
#    1226     return
#    1227 if _is_dlpack(data):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\data.py:545, in _meta_from_pandas_series(data, name, dtype, handle)
#     543     data = data.to_dense()  # type: ignore
#     544 assert len(data.shape) == 1 or data.shape[1] == 0 or data.shape[1] == 1
# --> 545 _meta_from_numpy(data, name, dtype, handle)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\data.py:1159, in _meta_from_numpy(data, field, dtype, handle)
#    1157     raise ValueError("Masked array is not supported.")
#    1158 interface_str = _array_interface(data)
# -> 1159 _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:282, in _check_call(ret)
#     271 """Check the return value of C API call
#     272
#     273 This function will raise exception when error occurs.
#    (...)
#     279     return value from API calls
#     280 """
#     281 if ret != 0:
# --> 282     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [14:59:57] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\data\data.cc:507: Check failed: valid: Label contains NaN, infinity or a value too large.

# %%
y_pred=xgb.predict(X_test)

# %%
submit=pd.DataFrame({'row_id':test['row_id'],'congestion':y_pred})

# %%
submit.to_csv('XGB_Tabular_Playground.csv',index=False)

# %%
#using cat boost

# %%
cat = CatBoostRegressor(random_state=24,subsample=1)

# %%
cat.fit(X_train, y_train)
# Out:
# Learning rate set to 0.118832
# 0:	learn: 16.2164740	total: 207ms	remaining: 3m 26s
# 1:	learn: 15.6971839	total: 257ms	remaining: 2m 8s
# 2:	learn: 15.2817988	total: 304ms	remaining: 1m 40s
# 3:	learn: 14.9439301	total: 351ms	remaining: 1m 27s
# 4:	learn: 14.5338280	total: 396ms	remaining: 1m 18s
# 5:	learn: 14.2272870	total: 448ms	remaining: 1m 14s
# 6:	learn: 13.9780228	total: 497ms	remaining: 1m 10s
# 7:	learn: 13.7847511	total: 547ms	remaining: 1m 7s
# 8:	learn: 13.5214270	total: 595ms	remaining: 1m 5s
# 9:	learn: 13.2960904	total: 643ms	remaining: 1m 3s
# 10:	learn: 13.1562954	total: 693ms	remaining: 1m 2s
# 11:	learn: 13.0199639	total: 739ms	remaining: 1m
# 12:	learn: 12.8465463	total: 787ms	remaining: 59.7s
# 13:	learn: 12.7326875	total: 837ms	remaining: 59s
# 14:	learn: 12.5986570	total: 882ms	remaining: 57.9s
# 15:	learn: 12.4775788	total: 931ms	remaining: 57.2s
# 16:	learn: 12.3955416	total: 977ms	remaining: 56.5s
# 17:	learn: 12.3298985	total: 1.02s	remaining: 55.9s
# 299:	learn: 11.2661140	total: 13.8s	remaining: 32.3s
# 300:	learn: 11.2661137	total: 13.9s	remaining: 32.2s
# 301:	learn: 11.2661135	total: 13.9s	remaining: 32.2s
# 302:	learn: 11.2661132	total: 14s	remaining: 32.1s
# 303:	learn: 11.2661129	total: 14s	remaining: 32.1s
# 304:	learn: 11.2661125	total: 14.1s	remaining: 32.1s
# 305:	learn: 11.2661124	total: 14.1s	remaining: 32s
# 306:	learn: 11.2661122	total: 14.2s	remaining: 32s
# 307:	learn: 11.2661119	total: 14.2s	remaining: 31.9s
# 308:	learn: 11.2661117	total: 14.3s	remaining: 31.9s
# 309:	learn: 11.2661115	total: 14.3s	remaining: 31.8s
# 310:	learn: 11.2661113	total: 14.3s	remaining: 31.8s
# 311:	learn: 11.2661111	total: 14.4s	remaining: 31.7s
# 312:	learn: 11.2661110	total: 14.4s	remaining: 31.7s
# 313:	learn: 11.2661109	total: 14.5s	remaining: 31.6s
# 314:	learn: 11.2661106	total: 14.5s	remaining: 31.6s
# 315:	learn: 11.2661105	total: 14.6s	remaining: 31.6s
# 316:	learn: 11.2661103	total: 14.6s	remaining: 31.5s
# 317:	learn: 11.2661102	total: 14.7s	remaining: 31.5s
# 318:	learn: 11.2661100	total: 14.7s	remaining: 31.4s
# 319:	learn: 11.2661099	total: 14.8s	remaining: 31.4s
# 320:	learn: 11.2661098	total: 14.8s	remaining: 31.3s
# 321:	learn: 11.2661095	total: 14.9s	remaining: 31.3s
# 322:	learn: 11.2661094	total: 14.9s	remaining: 31.2s
# 323:	learn: 11.2661092	total: 14.9s	remaining: 31.2s
# 324:	learn: 11.2661091	total: 15s	remaining: 31.1s
# 325:	learn: 11.2661089	total: 15s	remaining: 31.1s
# 326:	learn: 11.2661088	total: 15.1s	remaining: 31s
# 327:	learn: 11.2661087	total: 15.1s	remaining: 31s
# 328:	learn: 11.2661086	total: 15.2s	remaining: 31s
# 329:	learn: 11.2661085	total: 15.2s	remaining: 30.9s
# 330:	learn: 11.2661084	total: 15.3s	remaining: 30.9s
# 331:	learn: 11.2661082	total: 15.3s	remaining: 30.8s
# 332:	learn: 11.2661081	total: 15.4s	remaining: 30.8s
# 333:	learn: 11.2661080	total: 15.4s	remaining: 30.7s
# 334:	learn: 11.2661079	total: 15.5s	remaining: 30.7s
# 335:	learn: 11.2661077	total: 15.5s	remaining: 30.6s
# 336:	learn: 11.2661076	total: 15.5s	remaining: 30.6s
# 337:	learn: 11.2661075	total: 15.6s	remaining: 30.5s
# 338:	learn: 11.2661075	total: 15.6s	remaining: 30.5s
# 339:	learn: 11.2661073	total: 15.7s	remaining: 30.4s
# 340:	learn: 11.2661071	total: 15.7s	remaining: 30.4s
# 341:	learn: 11.2661071	total: 15.8s	remaining: 30.3s
# 342:	learn: 11.2661070	total: 15.8s	remaining: 30.3s
# 343:	learn: 11.2661069	total: 15.9s	remaining: 30.3s
# 344:	learn: 11.2661069	total: 15.9s	remaining: 30.2s
# 345:	learn: 11.2661068	total: 16s	remaining: 30.2s
# 346:	learn: 11.2661066	total: 16s	remaining: 30.1s
# 347:	learn: 11.2661066	total: 16.1s	remaining: 30.1s
# 348:	learn: 11.2661065	total: 16.1s	remaining: 30s
# 349:	learn: 11.2661064	total: 16.1s	remaining: 30s
# 350:	learn: 11.2661064	total: 16.2s	remaining: 29.9s
# 351:	learn: 11.2661063	total: 16.2s	remaining: 29.9s
# 352:	learn: 11.2661063	total: 16.3s	remaining: 29.8s
# 353:	learn: 11.2661062	total: 16.3s	remaining: 29.8s
# 354:	learn: 11.2661062	total: 16.4s	remaining: 29.7s
# 355:	learn: 11.2661061	total: 16.4s	remaining: 29.7s
# 356:	learn: 11.2661058	total: 16.5s	remaining: 29.7s
# 357:	learn: 11.2661057	total: 16.5s	remaining: 29.6s
# 358:	learn: 11.2661057	total: 16.6s	remaining: 29.6s
# 359:	learn: 11.2661056	total: 16.6s	remaining: 29.5s
# 360:	learn: 11.2661056	total: 16.7s	remaining: 29.5s
# 361:	learn: 11.2661056	total: 16.7s	remaining: 29.4s
# 362:	learn: 11.2661055	total: 16.7s	remaining: 29.4s
# 363:	learn: 11.2661055	total: 16.8s	remaining: 29.3s
# 364:	learn: 11.2661055	total: 16.8s	remaining: 29.3s
# 365:	learn: 11.2661055	total: 16.9s	remaining: 29.2s
# 366:	learn: 11.2661054	total: 16.9s	remaining: 29.2s
# 367:	learn: 11.2661054	total: 17s	remaining: 29.2s
# 368:	learn: 11.2661053	total: 17s	remaining: 29.1s
# 369:	learn: 11.2661053	total: 17.1s	remaining: 29.1s
# 370:	learn: 11.2661052	total: 17.1s	remaining: 29s
# 371:	learn: 11.2661052	total: 17.2s	remaining: 29s
# 372:	learn: 11.2661052	total: 17.2s	remaining: 28.9s
# 373:	learn: 11.2661051	total: 17.3s	remaining: 28.9s
# 374:	learn: 11.2661051	total: 17.3s	remaining: 28.9s
# 375:	learn: 11.2661050	total: 17.4s	remaining: 28.8s
# 376:	learn: 11.2661050	total: 17.4s	remaining: 28.8s
# 377:	learn: 11.2661049	total: 17.5s	remaining: 28.7s
# 378:	learn: 11.2661049	total: 17.5s	remaining: 28.7s
# 379:	learn: 11.2661049	total: 17.6s	remaining: 28.6s
# 380:	learn: 11.2661049	total: 17.6s	remaining: 28.6s
# 381:	learn: 11.2661048	total: 17.7s	remaining: 28.6s
# 382:	learn: 11.2661048	total: 17.7s	remaining: 28.5s
# 383:	learn: 11.2661048	total: 17.7s	remaining: 28.5s
# 384:	learn: 11.2661048	total: 17.8s	remaining: 28.4s
# 385:	learn: 11.2661047	total: 17.8s	remaining: 28.4s
# 386:	learn: 11.2661047	total: 17.9s	remaining: 28.3s
# 387:	learn: 11.2661047	total: 17.9s	remaining: 28.3s
# 388:	learn: 11.2661045	total: 18s	remaining: 28.2s
# 389:	learn: 11.2661045	total: 18s	remaining: 28.2s
# 390:	learn: 11.2661045	total: 18.1s	remaining: 28.1s
# 391:	learn: 11.2661044	total: 18.1s	remaining: 28.1s
# 392:	learn: 11.2661044	total: 18.2s	remaining: 28s
# 393:	learn: 11.2661043	total: 18.2s	remaining: 28s
# 394:	learn: 11.2661043	total: 18.2s	remaining: 27.9s
# 395:	learn: 11.2661043	total: 18.3s	remaining: 27.9s
# 396:	learn: 11.2661043	total: 18.3s	remaining: 27.9s
# 397:	learn: 11.2661043	total: 18.4s	remaining: 27.8s
# 398:	learn: 11.2661043	total: 18.4s	remaining: 27.8s
# 399:	learn: 11.2661043	total: 18.5s	remaining: 27.7s
# 400:	learn: 11.2661043	total: 18.5s	remaining: 27.7s
# 401:	learn: 11.2661043	total: 18.6s	remaining: 27.6s
# 402:	learn: 11.2661043	total: 18.6s	remaining: 27.6s
# 403:	learn: 11.2661042	total: 18.7s	remaining: 27.5s
# 404:	learn: 11.2661042	total: 18.7s	remaining: 27.5s
# 405:	learn: 11.2661042	total: 18.8s	remaining: 27.4s
# 406:	learn: 11.2661042	total: 18.8s	remaining: 27.4s
# 407:	learn: 11.2661042	total: 18.8s	remaining: 27.3s
# 408:	learn: 11.2661042	total: 18.9s	remaining: 27.3s
# 409:	learn: 11.2661042	total: 18.9s	remaining: 27.2s
# 410:	learn: 11.2661041	total: 19s	remaining: 27.2s
# 411:	learn: 11.2661041	total: 19s	remaining: 27.1s
# 412:	learn: 11.2661041	total: 19.1s	remaining: 27.1s
# 413:	learn: 11.2661041	total: 19.1s	remaining: 27.1s
# 414:	learn: 11.2661041	total: 19.2s	remaining: 27s
# 415:	learn: 11.2661041	total: 19.2s	remaining: 27s
# 416:	learn: 11.2661041	total: 19.2s	remaining: 26.9s
# 417:	learn: 11.2661041	total: 19.3s	remaining: 26.9s
# 418:	learn: 11.2661041	total: 19.3s	remaining: 26.8s
# 419:	learn: 11.2661041	total: 19.4s	remaining: 26.8s
# 420:	learn: 11.2661041	total: 19.4s	remaining: 26.7s
# 421:	learn: 11.2661041	total: 19.5s	remaining: 26.7s
# 422:	learn: 11.2661041	total: 19.5s	remaining: 26.6s
# 423:	learn: 11.2661041	total: 19.6s	remaining: 26.6s
# 424:	learn: 11.2661041	total: 19.6s	remaining: 26.5s
# 425:	learn: 11.2661041	total: 19.7s	remaining: 26.5s
# 426:	learn: 11.2661040	total: 19.7s	remaining: 26.4s
# 427:	learn: 11.2661040	total: 19.7s	remaining: 26.4s
# 428:	learn: 11.2661040	total: 19.8s	remaining: 26.3s
# 429:	learn: 11.2661040	total: 19.8s	remaining: 26.3s
# 430:	learn: 11.2661040	total: 19.9s	remaining: 26.2s
# 431:	learn: 11.2661040	total: 19.9s	remaining: 26.2s
# 432:	learn: 11.2661040	total: 20s	remaining: 26.1s
# 433:	learn: 11.2661040	total: 20s	remaining: 26.1s
# 434:	learn: 11.2661040	total: 20.1s	remaining: 26.1s
# 435:	learn: 11.2661040	total: 20.1s	remaining: 26s
# 436:	learn: 11.2661040	total: 20.1s	remaining: 26s
# 437:	learn: 11.2661040	total: 20.2s	remaining: 25.9s
# 438:	learn: 11.2661039	total: 20.2s	remaining: 25.9s
# 439:	learn: 11.2661039	total: 20.3s	remaining: 25.8s
# 909:	learn: 11.2661037	total: 41.7s	remaining: 4.13s
# 910:	learn: 11.2661037	total: 41.8s	remaining: 4.08s
# 911:	learn: 11.2661037	total: 41.8s	remaining: 4.03s
# 912:	learn: 11.2661037	total: 41.9s	remaining: 3.99s
# 913:	learn: 11.2661037	total: 41.9s	remaining: 3.94s
# 914:	learn: 11.2661037	total: 41.9s	remaining: 3.9s
# 915:	learn: 11.2661037	total: 42s	remaining: 3.85s
# 916:	learn: 11.2661037	total: 42s	remaining: 3.8s
# 917:	learn: 11.2661037	total: 42.1s	remaining: 3.76s
# 918:	learn: 11.2661037	total: 42.1s	remaining: 3.71s
# 919:	learn: 11.2661037	total: 42.2s	remaining: 3.67s
# 920:	learn: 11.2661037	total: 42.2s	remaining: 3.62s
# 921:	learn: 11.2661037	total: 42.3s	remaining: 3.58s
# 922:	learn: 11.2661037	total: 42.3s	remaining: 3.53s
# 923:	learn: 11.2661037	total: 42.4s	remaining: 3.48s
# 924:	learn: 11.2661037	total: 42.4s	remaining: 3.44s
# 925:	learn: 11.2661037	total: 42.4s	remaining: 3.39s
# 926:	learn: 11.2661037	total: 42.5s	remaining: 3.35s
# 927:	learn: 11.2661037	total: 42.5s	remaining: 3.3s
# 928:	learn: 11.2661037	total: 42.6s	remaining: 3.25s
# 929:	learn: 11.2661037	total: 42.6s	remaining: 3.21s
# 930:	learn: 11.2661037	total: 42.7s	remaining: 3.16s
# 931:	learn: 11.2661037	total: 42.7s	remaining: 3.12s
# 932:	learn: 11.2661037	total: 42.8s	remaining: 3.07s
# 933:	learn: 11.2661037	total: 42.8s	remaining: 3.02s
# 934:	learn: 11.2661037	total: 42.8s	remaining: 2.98s
# 935:	learn: 11.2661037	total: 42.9s	remaining: 2.93s
# 936:	learn: 11.2661037	total: 42.9s	remaining: 2.89s
# 937:	learn: 11.2661037	total: 43s	remaining: 2.84s
# 938:	learn: 11.2661037	total: 43s	remaining: 2.79s
# 939:	learn: 11.2661037	total: 43.1s	remaining: 2.75s
# 940:	learn: 11.2661037	total: 43.1s	remaining: 2.7s
# 941:	learn: 11.2661037	total: 43.2s	remaining: 2.66s
# 942:	learn: 11.2661037	total: 43.2s	remaining: 2.61s
# 943:	learn: 11.2661037	total: 43.3s	remaining: 2.57s
# 944:	learn: 11.2661037	total: 43.3s	remaining: 2.52s
# 945:	learn: 11.2661037	total: 43.4s	remaining: 2.47s
# 946:	learn: 11.2661037	total: 43.4s	remaining: 2.43s
# 947:	learn: 11.2661037	total: 43.5s	remaining: 2.38s
# 948:	learn: 11.2661037	total: 43.5s	remaining: 2.34s
# 949:	learn: 11.2661037	total: 43.5s	remaining: 2.29s
# 950:	learn: 11.2661037	total: 43.6s	remaining: 2.25s
# 951:	learn: 11.2661037	total: 43.6s	remaining: 2.2s
# 952:	learn: 11.2661037	total: 43.7s	remaining: 2.15s
# 953:	learn: 11.2661037	total: 43.7s	remaining: 2.11s
# 954:	learn: 11.2661037	total: 43.8s	remaining: 2.06s
# 955:	learn: 11.2661037	total: 43.8s	remaining: 2.02s
# 956:	learn: 11.2661037	total: 43.9s	remaining: 1.97s
# 957:	learn: 11.2661037	total: 43.9s	remaining: 1.92s
# 958:	learn: 11.2661037	total: 44s	remaining: 1.88s
# 959:	learn: 11.2661037	total: 44s	remaining: 1.83s
# 960:	learn: 11.2661037	total: 44s	remaining: 1.79s
# 961:	learn: 11.2661037	total: 44.1s	remaining: 1.74s
# 962:	learn: 11.2661037	total: 44.1s	remaining: 1.7s
# 963:	learn: 11.2661037	total: 44.2s	remaining: 1.65s
# 964:	learn: 11.2661037	total: 44.2s	remaining: 1.6s
# 965:	learn: 11.2661037	total: 44.3s	remaining: 1.56s
# 966:	learn: 11.2661037	total: 44.3s	remaining: 1.51s
# 967:	learn: 11.2661037	total: 44.4s	remaining: 1.47s
# 968:	learn: 11.2661037	total: 44.4s	remaining: 1.42s
# 969:	learn: 11.2661037	total: 44.4s	remaining: 1.37s
# 970:	learn: 11.2661037	total: 44.5s	remaining: 1.33s
# 971:	learn: 11.2661037	total: 44.5s	remaining: 1.28s
# 972:	learn: 11.2661037	total: 44.6s	remaining: 1.24s
# 973:	learn: 11.2661037	total: 44.6s	remaining: 1.19s
# 974:	learn: 11.2661037	total: 44.7s	remaining: 1.15s
# 975:	learn: 11.2661037	total: 44.7s	remaining: 1.1s
# 976:	learn: 11.2661037	total: 44.8s	remaining: 1.05s
# 977:	learn: 11.2661037	total: 44.8s	remaining: 1.01s
# 978:	learn: 11.2661037	total: 44.8s	remaining: 962ms
# 979:	learn: 11.2661037	total: 44.9s	remaining: 916ms
# 980:	learn: 11.2661037	total: 44.9s	remaining: 870ms
# 981:	learn: 11.2661037	total: 45s	remaining: 825ms
# 982:	learn: 11.2661037	total: 45s	remaining: 779ms
# 983:	learn: 11.2661037	total: 45.1s	remaining: 733ms
# 984:	learn: 11.2661037	total: 45.1s	remaining: 687ms
# 985:	learn: 11.2661037	total: 45.2s	remaining: 641ms
# 986:	learn: 11.2661037	total: 45.2s	remaining: 595ms
# 987:	learn: 11.2661037	total: 45.3s	remaining: 550ms
# 988:	learn: 11.2661037	total: 45.3s	remaining: 504ms
# 989:	learn: 11.2661037	total: 45.3s	remaining: 458ms
# 990:	learn: 11.2661037	total: 45.4s	remaining: 412ms
# 991:	learn: 11.2661037	total: 45.4s	remaining: 366ms
# 992:	learn: 11.2661037	total: 45.5s	remaining: 321ms
# 993:	learn: 11.2661037	total: 45.5s	remaining: 275ms
# 994:	learn: 11.2661037	total: 45.6s	remaining: 229ms
# 995:	learn: 11.2661037	total: 45.6s	remaining: 183ms
# 996:	learn: 11.2661037	total: 45.7s	remaining: 137ms
# 997:	learn: 11.2661037	total: 45.7s	remaining: 91.6ms
# 998:	learn: 11.2661037	total: 45.7s	remaining: 45.8ms
# 999:	learn: 11.2661037	total: 45.8s	remaining: 0us

# %%
y_pred=cat.predict(X_test)

# %%
submit=pd.DataFrame({'row_id':test['row_id'],'congestion':y_pred})

# %%
submit.to_csv('Cat_Tabular_Playground_without_time.csv',index=False)
